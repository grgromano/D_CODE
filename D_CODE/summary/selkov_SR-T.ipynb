# %% [markdown]
# ### Sel'kov Model - SR-T performance:

# %%
# add the parent directory to the system path:
import sys
from pathlib import Path
parent_dir = Path('..').resolve() 
sys.path.append(str(parent_dir)) 

# import:
import numpy as np
import os
import matplotlib.pyplot as plt
from evaluation_trajectories import evaluation2D, evaluation2D_partial, evaluation2D_p, evaluation2D_partial_p

# seed:
np.random.seed(666)

# %% [markdown]
# ### Standard:

# %%
# select the ODE:
ode_name = 'SelkovODE'
init_high = [0.05, 0.05]
init_low = [0.05, 0.05]

ode_param=None
x_id = 0
freq = 10
n_sample = 50 
noise_ratio = 0.01
alg = 'diff'
seed = 0
n_seed = 5

# %%
# Partial Reconstruction: Equation 1 only
# evaluation: 
xt_true, est_trajectories, rmse = evaluation2D_partial(ode_name, ode_param, x_id, freq, n_sample, noise_ratio, alg, seed, n_seed, init_high, init_low)
print('RMSE on test-case 0: ', rmse)

# plot:
plt.figure(figsize=(5, 4))

for i in range(np.shape(est_trajectories)[0]):
    plt.plot(est_trajectories[i][:, 0, 0], est_trajectories[i][:, 0, 1], color='blue', linewidth=0.5, alpha=0.7)

plt.plot(xt_true[:, 0, 0], xt_true[:, 0, 1], color='red', linewidth=1.0, label='Correct Trajectory')

plt.scatter(xt_true[:, 0, 0][0], xt_true[:, 0, 1][0], color='green', label='Start')
plt.scatter(xt_true[:, 0, 0][-1], xt_true[:, 0, 1][-1], color='red', label='End')

plt.title('Partial Reconstruction: Equation 1 only')
plt.legend()
plt.grid(True)
# Out:
# 5
# 0.8
# [0.034731844139105746, 0.13326205898191565, 0.047938078639929965, 0.02001786161290271, 0.018749689854622865]
# RMSE on test-case 0:  0.050939906645695386

# %% [markdown]
# RMK. è strano che a differenza dei casi nell'altro notebook in questo caso l'errore sembra aumentare all'aumentare del tempo, mentre negli altri casi l'errore si oncentra solo nelle curve e tutte le trajectories si concludono nello stesso punto, quello corretto -> verificare che non ci siano errori

# %%
# Partial Reconstruction: Equation 2 only
# evaluation: 
xt_true, est_trajectories, rmse = evaluation2D_partial(ode_name, ode_param, 1, freq, n_sample, noise_ratio, alg, seed, n_seed, init_high, init_low)
print('RMSE on test-case 0: ', rmse)

# plot:
plt.figure(figsize=(5, 4))

for i in range(np.shape(est_trajectories)[0]):
    plt.plot(est_trajectories[i][:, 0, 0], est_trajectories[i][:, 0, 1], color='blue', linewidth=0.5, alpha=0.7)

plt.plot(xt_true[:, 0, 0], xt_true[:, 0, 1], color='red', linewidth=1.0, label='Correct Trajectory')

plt.scatter(xt_true[:, 0, 0][0], xt_true[:, 0, 1][0], color='green', label='Start')
plt.scatter(xt_true[:, 0, 0][-1], xt_true[:, 0, 1][-1], color='red', label='End')

plt.title('Partial Reconstruction: Equation 2 only')
plt.legend()
plt.grid(True)
# Out:
# 5
# 0.8
# [6.649602310663827e-05, 0.018213362423640654, 0.030745447571743502, 0.009006866078803974, 0.00866534760115595]
# RMSE on test-case 0:  0.013339503939690144

# %%
# Total Reconstruction
# evaluation: 
xt_true, est_trajectories, rmse = evaluation2D(ode_name, ode_param, x_id, freq, n_sample, noise_ratio, alg, seed, n_seed, init_high, init_low)
print('RMSE on test-case 0: ', rmse)

# plot:
plt.figure(figsize=(5, 4))

for i in range(np.shape(est_trajectories)[0]):
    plt.plot(est_trajectories[i][:, 0, 0], est_trajectories[i][:, 0, 1], color='blue', linewidth=0.5, alpha=0.7)

plt.plot(xt_true[:, 0, 0], xt_true[:, 0, 1], color='red', linewidth=1.0, label='Correct Trajectory')

plt.scatter(xt_true[:, 0, 0][0], xt_true[:, 0, 1][0], color='green', label='Start')
plt.scatter(xt_true[:, 0, 0][-1], xt_true[:, 0, 1][-1], color='red', label='End')

plt.title(r'Estimated Trajectories, No Param.')
plt.legend()
plt.grid(True)
# Out:
# 5
# 0.8
# 0.8
# [0.03466703333641628, 0.13772806388044656, 0.07251280202989391, 0.01790361174391391, 0.026619212413044716]
# RMSE on test-case 0:  0.05788614468074307

# %% [markdown]
# ### Parametrization on $\rho$

# %%
# select the ODE:
ode_name = 'SelkovODE_rho'
init_high = [0.05, 0.05, 0.75]
init_low = [0.05, 0.05, 0.75]

ode_param=None
x_id = 0
freq = 10
n_sample = 50 
noise_ratio = 0.01
alg = 'diff'
seed = 0
n_seed = 5

# %%
# Partial Reconstruction: Equation 1 only
# evaluation: 
xt_true_r, est_trajectories_r, rmse_r = evaluation2D_partial_p(ode_name, ode_param, x_id, freq, n_sample, noise_ratio, alg, seed, n_seed, init_high, init_low)
print('RMSE on test-case 0: ', rmse_r)

# plot:
plt.figure(figsize=(5, 4))

for i in range(np.shape(est_trajectories_r)[0]):
    plt.plot(est_trajectories_r[i][:, 0, 0], est_trajectories_r[i][:, 0, 1], color='blue', linewidth=0.5, alpha=0.7)

plt.plot(xt_true_r[:, 0, 0], xt_true_r[:, 0, 1], color='red', linewidth=1.0, label='Correct Trajectory')

plt.scatter(xt_true_r[:, 0, 0][0], xt_true_r[:, 0, 1][0], color='green', label='Start')
plt.scatter(xt_true_r[:, 0, 0][-1], xt_true_r[:, 0, 1][-1], color='red', label='End')

plt.title('Partial Reconstruction: Equation 1 only')
plt.legend()
plt.grid(True)
# Out:
# 5
# 0.8
# [0.04970107268023294, 0.006203620618802805, 0.013628867655576114, 0.0033398311676046946, 0.001039952892505561]
# RMSE on test-case 0:  0.014782669002944424

# %%
# Partial Reconstruction: Equation 2 only
# evaluation: 
xt_true_r, est_trajectories_r, rmse_r = evaluation2D_partial_p(ode_name, ode_param, 1, freq, n_sample, noise_ratio, alg, seed, n_seed, init_high, init_low)
print('RMSE on test-case 0: ', rmse_r)

# plot:
plt.figure(figsize=(5, 4))

for i in range(np.shape(est_trajectories_r)[0]):
    plt.plot(est_trajectories_r[i][:, 0, 0], est_trajectories_r[i][:, 0, 1], color='blue', linewidth=0.5, alpha=0.7)

plt.plot(xt_true_r[:, 0, 0], xt_true_r[:, 0, 1], color='red', linewidth=1.0, label='Correct Trajectory')

plt.scatter(xt_true_r[:, 0, 0][0], xt_true_r[:, 0, 1][0], color='green', label='Start')
plt.scatter(xt_true_r[:, 0, 0][-1], xt_true_r[:, 0, 1][-1], color='red', label='End')

plt.title('Partial Reconstruction: Equation 2 only')
plt.legend()
plt.grid(True)
# Out:
# 5
# 0.4
# [0.018000151322107902, 0.4444735058580861, 1.5811130160892528, 0.00994976070534673, 0.009261880188056421]
# RMSE on test-case 0:  0.41255966283257006

# %%
# Total Reconstruction
# evaluation: 
xt_true_r, est_trajectories_r, rmse_r = evaluation2D_p(ode_name, ode_param, x_id, freq, n_sample, noise_ratio, alg, seed, n_seed, init_high, init_low)
print('RMSE on test-case 0: ', rmse_r)

# plot:
plt.figure(figsize=(5, 4))

for i in range(np.shape(est_trajectories_r)[0]):
    plt.plot(est_trajectories_r[i][:, 0, 0], est_trajectories_r[i][:, 0, 1], color='blue', linewidth=0.5, alpha=0.7)

plt.plot(xt_true_r[:, 0, 0], xt_true_r[:, 0, 1], color='red', linewidth=1.0, label='Correct Trajectory')

plt.scatter(xt_true_r[:, 0, 0][0], xt_true_r[:, 0, 1][0], color='green', label='Start')
plt.scatter(xt_true_r[:, 0, 0][-1], xt_true_r[:, 0, 1][-1], color='red', label='End')

plt.title(r'Estimated Trajectories, Param. $\rho$')
plt.legend()
plt.grid(True)
# Out:
# 5
# 0.8
# 0.4
# [0.03575617919017278, 0.4480079812148559, 1.5877259611773422, 0.013069369825368979, 0.008326310002664133]
# RMSE on test-case 0:  0.41857716028208075

# %%
# RMSE:

N = 50
a, b = 0.0, 0.1  # first input interval
c, d = 0.0, 0.1  # second input interval
e, f = 0.7, 0.8  # third input interval
init_point = np.empty((N, 3))
init_point[:, 0] = np.random.uniform(a, b, N) 
init_point[:, 1] = np.random.uniform(c, d, N) 
init_point[:, 2] = np.random.uniform(e, f, N)           
#print(init_point)
#print(np.shape(init_point))
#init_point = [[0.003, 1.3], [0.005, 1.5], [0.007, 1.7]]

RMSE_rho = evaluation2D_p(ode_name, ode_param, x_id, freq, n_sample, noise_ratio, alg, seed, n_seed, init_high, init_low, N, init_point)
print('RMSE (overall): ', RMSE_rho)
# Out:
# 5
# 0.8
# 0.4
# [0.0355286389274003, 0.4476448924515675, 1.6285275136182842, 0.0129850099541431, 0.008275758057049751]
# RMSE (overall):  0.4265923626016891

# %% [markdown]
# ### Bifurcation Test:

# %% [markdown]
# ##### $\rho \simeq 0.9$

# %%
# select the ODE:
ode_name = 'SelkovODE_rho'
init_high = [0.05, 0.05, 0.9]
init_low = [0.05, 0.05, 0.9]

ode_param=None
x_id = 0
freq = 10
n_sample = 50 
noise_ratio = 0.01
alg = 'diff'
seed = 0
n_seed = 5

# %%
# Total Reconstruction
# evaluation: 
xt_true_r, est_trajectories_r, rmse_r = evaluation2D_p(ode_name, ode_param, x_id, freq, n_sample, noise_ratio, alg, seed, n_seed, init_high, init_low)
print('RMSE on test-case 0: ', rmse_r)

# plot:
plt.figure(figsize=(5, 4))

for i in range(np.shape(est_trajectories_r)[0]):
    plt.plot(est_trajectories_r[i][:, 0, 0], est_trajectories_r[i][:, 0, 1], color='blue', linewidth=0.5, alpha=0.7)

plt.plot(xt_true_r[:, 0, 0], xt_true_r[:, 0, 1], color='red', linewidth=1.0, label='Correct Trajectory')

plt.scatter(xt_true_r[:, 0, 0][0], xt_true_r[:, 0, 1][0], color='green', label='Start')
plt.scatter(xt_true_r[:, 0, 0][-1], xt_true_r[:, 0, 1][-1], color='red', label='End')

plt.title(r'Estimated Trajectories, $\rho \simeq 0.9$')
plt.legend()
plt.grid(True)
# Out:
# 5
# 0.8
# 0.4
# [0.02563056026459127, 0.5076997978843292, 2.4702522194457295, 0.010808836625453816, 0.007296167830186155]
# RMSE on test-case 0:  0.604337516410058

# %%
# RMSE:

N = 50
a, b = 0.0, 0.1  # first input interval
c, d = 0.0, 0.1  # second input interval
e, f = 0.85, 0.95  # third input interval
init_point = np.empty((N, 3))
init_point[:, 0] = np.random.uniform(a, b, N) 
init_point[:, 1] = np.random.uniform(c, d, N) 
init_point[:, 2] = np.random.uniform(e, f, N)           

RMSE_rho = evaluation2D_p(ode_name, ode_param, x_id, freq, n_sample, noise_ratio, alg, seed, n_seed, init_high, init_low, N, init_point)
print('RMSE (overall): ', RMSE_rho)
# Out:
# 5
# 0.8
# 0.4
# [0.026099052071136532, 0.5091420235911209, 2.408573748153908, 0.010918196758955678, 0.007352941686951913]
# RMSE (overall):  0.5924171924524145

# %% [markdown]
# ##### $\rho \simeq 0.6$

# %%
# select the ODE:
ode_name = 'SelkovODE_rho'
init_high = [0.05, 0.05, 0.6]
init_low = [0.05, 0.05, 0.6]

ode_param=None
x_id = 0
freq = 10
n_sample = 50 
noise_ratio = 0.01
alg = 'diff'
seed = 0
n_seed = 5

# %%
# Total Reconstruction
# evaluation: 
xt_true_r, est_trajectories_r, rmse_r = evaluation2D_p(ode_name, ode_param, x_id, freq, n_sample, noise_ratio, alg, seed, n_seed, init_high, init_low)
print('RMSE on test-case 0: ', rmse_r)

# plot:
plt.figure(figsize=(5, 4))

for i in range(np.shape(est_trajectories_r)[0]):
    plt.plot(est_trajectories_r[i][:, 0, 0], est_trajectories_r[i][:, 0, 1], color='blue', linewidth=0.5, alpha=0.7)

plt.plot(xt_true_r[:, 0, 0], xt_true_r[:, 0, 1], color='red', linewidth=1.0, label='Correct Trajectory')

plt.scatter(xt_true_r[:, 0, 0][0], xt_true_r[:, 0, 1][0], color='green', label='Start')
plt.scatter(xt_true_r[:, 0, 0][-1], xt_true_r[:, 0, 1][-1], color='red', label='End')

plt.title(r'Estimated Trajectories, $\rho \simeq 0.6$')
plt.legend()
plt.grid(True)
# Out:
# 5
# 0.8
# 0.4
# [0.03274694309083495, 0.3264267000047406, 1.1596643406165583, 0.009752198893673994, 0.005913934713532033]
# RMSE on test-case 0:  0.306900823463868

# %%
# RMSE:

N = 50
a, b = 0.0, 0.1  # first input interval
c, d = 0.0, 0.1  # second input interval
e, f = 0.55, 0.65  # third input interval
init_point = np.empty((N, 3))
init_point[:, 0] = np.random.uniform(a, b, N) 
init_point[:, 1] = np.random.uniform(c, d, N) 
init_point[:, 2] = np.random.uniform(e, f, N)           

RMSE_rho = evaluation2D_p(ode_name, ode_param, x_id, freq, n_sample, noise_ratio, alg, seed, n_seed, init_high, init_low, N, init_point)
print('RMSE (overall): ', RMSE_rho)
# Out:
# 5
# 0.8
# 0.4
# [0.03360465491298366, 0.3236503462668766, 1.1881451630067619, 0.009930385524759, 0.006024847723477092]
# RMSE (overall):  0.31227107948697164

# %% [markdown]
# ##### $\rho \simeq 0.4$

# %%
# select the ODE:
ode_name = 'SelkovODE_rho'
init_high = [0.05, 0.05, 0.4]
init_low = [0.05, 0.05, 0.4]

ode_param=None
x_id = 0
freq = 10
n_sample = 50 
noise_ratio = 0.01
alg = 'diff'
seed = 0
n_seed = 5

# %%
# Total Reconstruction
# evaluation: 
xt_true_r, est_trajectories_r, rmse_r = evaluation2D_p(ode_name, ode_param, x_id, freq, n_sample, noise_ratio, alg, seed, n_seed, init_high, init_low)
print('RMSE on test-case 0: ', rmse_r)

# plot:
plt.figure(figsize=(5, 4))

for i in range(np.shape(est_trajectories_r)[0]):
    plt.plot(est_trajectories_r[i][:, 0, 0], est_trajectories_r[i][:, 0, 1], color='blue', linewidth=0.5, alpha=0.7)

plt.plot(xt_true_r[:, 0, 0], xt_true_r[:, 0, 1], color='red', linewidth=1.0, label='Correct Trajectory')

plt.scatter(xt_true_r[:, 0, 0][0], xt_true_r[:, 0, 1][0], color='green', label='Start')
plt.scatter(xt_true_r[:, 0, 0][-1], xt_true_r[:, 0, 1][-1], color='red', label='End')

plt.title(r'Estimated Trajectories, $\rho \simeq 0.4$')
plt.legend()
plt.grid(True)
# Out:
# 5
# 0.8
# 0.4
# [0.037864480156662134, 0.20595058012441286, 0.4900322802697685, 0.006697773581649387, 0.0037490199382551694]
# RMSE on test-case 0:  0.1488588268141496

# %%
# RMSE:

N = 50
a, b = 0.0, 0.1  # first input interval
c, d = 0.0, 0.1  # second input interval
e, f = 0.35, 0.45  # third input interval
init_point = np.empty((N, 3))
init_point[:, 0] = np.random.uniform(a, b, N) 
init_point[:, 1] = np.random.uniform(c, d, N) 
init_point[:, 2] = np.random.uniform(e, f, N)           

RMSE_rho = evaluation2D_p(ode_name, ode_param, x_id, freq, n_sample, noise_ratio, alg, seed, n_seed, init_high, init_low, N, init_point)
print('RMSE (overall): ', RMSE_rho)
# Out:
# 5
# 0.8
# 0.4
# [0.03574896788235518, 0.20234233761107223, 0.5280605416708056, 0.006612605977649377, 0.003747902555423485]
# RMSE (overall):  0.15530247113946116

# %% [markdown]
# ### Parametrization on $\sigma$

# %%
# select the ODE:
ode_name = 'SelkovODE_sigma'
init_high = [0.05, 0.05, 0.1]
init_low = [0.05, 0.05, 0.1]

ode_param=None
x_id = 0
freq = 10
n_sample = 50 
noise_ratio = 0.01
alg = 'diff'
seed = 0
n_seed = 5

# %%
# Partial Reconstruction: Equation 1 only
# evaluation: 
xt_true_s, est_trajectories_s, rmse_s = evaluation2D_partial_p(ode_name, ode_param, x_id, freq, n_sample, noise_ratio, alg, seed, n_seed, init_high, init_low)
print('RMSE on test-case 0: ', rmse_s)

# plot:
plt.figure(figsize=(5, 4))

for i in range(np.shape(est_trajectories_s)[0]):
    plt.plot(est_trajectories_s[i][:, 0, 0], est_trajectories_s[i][:, 0, 1], color='blue', linewidth=0.5, alpha=0.7)

plt.plot(xt_true_s[:, 0, 0], xt_true_s[:, 0, 1], color='red', linewidth=1.0, label='Correct Trajectory')

plt.scatter(xt_true_s[:, 0, 0][0], xt_true_s[:, 0, 1][0], color='green', label='Start')
plt.scatter(xt_true_s[:, 0, 0][-1], xt_true_s[:, 0, 1][-1], color='red', label='End')

plt.title('Partial Reconstruction: Equation 1 only')
plt.legend()
plt.grid(True)
# Out:
# 5
# 1.0
# [0.0005913897721935174, 0.036287990142267045, 0.000637648038803885, 0.021091006875774553, 0.006154557283568642]
# RMSE on test-case 0:  0.012952518422521528

# %%
# Partial Reconstruction: Equation 2 only
# evaluation: 
xt_true_s, est_trajectories_s, rmse_s = evaluation2D_partial_p(ode_name, ode_param, 1, freq, n_sample, noise_ratio, alg, seed, n_seed, init_high, init_low)
print('RMSE on test-case 0: ', rmse_s)

# plot:
plt.figure(figsize=(5, 4))

for i in range(np.shape(est_trajectories_s)[0]):
    plt.plot(est_trajectories_s[i][:, 0, 0], est_trajectories_s[i][:, 0, 1], color='blue', linewidth=0.5, alpha=0.7)

plt.plot(xt_true_s[:, 0, 0], xt_true_s[:, 0, 1], color='red', linewidth=1.0, label='Correct Trajectory')

plt.scatter(xt_true_s[:, 0, 0][0], xt_true_s[:, 0, 1][0], color='green', label='Start')
plt.scatter(xt_true_s[:, 0, 0][-1], xt_true_s[:, 0, 1][-1], color='red', label='End')

plt.title('Partial Reconstruction: Equation 2 only')
plt.legend()
plt.grid(True)
# Out:
# 5
# 1.0
# [1.760038456457817e-13, 0.0, 2.253540241197325e-14, 0.0, 1.323945383476104e-13]
# RMSE on test-case 0:  6.618675728107307e-14

# %%
# Total Reconstruction
# evaluation: 
xt_true_s, est_trajectories_s, rmse_s = evaluation2D_p(ode_name, ode_param, x_id, freq, n_sample, noise_ratio, alg, seed, n_seed, init_high, init_low)
print('RMSE on test-case 0: ', rmse_s)

# plot:
plt.figure(figsize=(5, 4))

for i in range(np.shape(est_trajectories_s)[0]):
    plt.plot(est_trajectories_s[i][:, 0, 0], est_trajectories_s[i][:, 0, 1], color='blue', linewidth=0.5, alpha=0.7)

plt.plot(xt_true_s[:, 0, 0], xt_true_s[:, 0, 1], color='red', linewidth=1.0, label='Correct Trajectory')

plt.scatter(xt_true_s[:, 0, 0][0], xt_true_s[:, 0, 1][0], color='green', label='Start')
plt.scatter(xt_true_s[:, 0, 0][-1], xt_true_s[:, 0, 1][-1], color='red', label='End')

plt.title(r'Estimated Trajectories, Param. $\sigma$')
plt.legend()
plt.grid(True)
# Out:
# 5
# 1.0
# 1.0
# [0.0005913897721900828, 0.036287990142267045, 0.0006376480387877831, 0.021091006875774553, 0.006154557283559969]
# RMSE on test-case 0:  0.012952518422515885

# %%
# RMSE:

N = 50
a, b = 0.0, 0.1  # first input interval
c, d = 0.0, 0.1  # second input interval
e, f = 0.05, 0.15  # third input interval
init_point = np.empty((N, 3))
init_point[:, 0] = np.random.uniform(a, b, N) 
init_point[:, 1] = np.random.uniform(c, d, N) 
init_point[:, 2] = np.random.uniform(e, f, N)           

RMSE_sigma = evaluation2D_p(ode_name, ode_param, x_id, freq, n_sample, noise_ratio, alg, seed, n_seed, init_high, init_low, N, init_point)
print('RMSE (overall): ', RMSE_sigma)
# Out:
# 5
# 1.0
# 1.0
# [0.0007095338660596731, 0.04297307803259542, 0.0007651064396114983, 0.025115978252625376, 0.007368591719119856]
# RMSE (overall):  0.015386457662002365

# %% [markdown]
# ### plot x report:

# %%
fig, axs = plt.subplots(1, 3, figsize=(16, 4))

for i in range(np.shape(est_trajectories)[0]):
    axs[0].plot(est_trajectories[i][:, 0, 0], est_trajectories[i][:, 0, 1], color='blue', linewidth=0.5, alpha=0.7)
axs[0].plot(xt_true[:, 0, 0], xt_true[:, 0, 1], color='red', linewidth=1.0, label='Correct Trajectory')
axs[0].scatter(xt_true[:, 0, 0][0], xt_true[:, 0, 1][0], color='green', label='Start')
axs[0].scatter(xt_true[:, 0, 0][-1], xt_true[:, 0, 1][-1], color='red', label='End')
axs[0].set_title('Estimated Trajectories - No Param.')
axs[0].legend()
axs[0].grid(True) 

for i in range(np.shape(est_trajectories_r)[0]):
    axs[1].plot(est_trajectories_r[i][:, 0, 0], est_trajectories_r[i][:, 0, 1], color='blue', linewidth=0.5, alpha=0.7)
axs[1].plot(xt_true_r[:, 0, 0], xt_true_r[:, 0, 1], color='red', linewidth=1.0, label='Correct Trajectory')
axs[1].scatter(xt_true_r[:, 0, 0][0], xt_true_r[:, 0, 1][0], color='green', label='Start')
axs[1].scatter(xt_true_r[:, 0, 0][-1], xt_true_r[:, 0, 1][-1], color='red', label='End')
axs[1].set_title(r'Estimated Trajectories - Param. $\rho$')
axs[1].legend()
axs[1].grid(True)

for i in range(np.shape(est_trajectories_s)[0]):
    axs[2].plot(est_trajectories_s[i][:, 0, 0], est_trajectories_s[i][:, 0, 1], color='blue', linewidth=0.5, alpha=0.7)
axs[2].plot(xt_true_s[:, 0, 0], xt_true_s[:, 0, 1], color='red', linewidth=1.0, label='Correct Trajectory')
axs[2].scatter(xt_true_s[:, 0, 0][0], xt_true_s[:, 0, 1][0], color='green', label='Start')
axs[2].scatter(xt_true_s[:, 0, 0][-1], xt_true_s[:, 0, 1][-1], color='red', label='End')
axs[2].set_title(r'Estimated Trajectories - Param. $\sigma$')
axs[2].legend()
axs[2].grid(True)

# %%
rmse = round(rmse, 4)
rmse_r = round(rmse_r, 4)
rmse_s = round(rmse_s, 4)

fig, axs = plt.subplots(1, 3, figsize=(16, 0.5))

axs[0].text(0.5, 0.5, f'RMSE on trajectories: {rmse}', ha='center', va='center', fontsize=12)
axs[0].axis('off')

axs[1].text(0.5, 0.5, f'RMSE on trajectories: {rmse_r}', ha='center', va='center', fontsize=12)
axs[1].axis('off')

axs[2].text(0.5, 0.5, f'RMSE on trajectories: {rmse_s}', ha='center', va='center', fontsize=12)
axs[2].axis('off')

plt.show()
