# %% [markdown]
# ##### Sel'kov Bifurcation - D-CODE performance

# %%
# add the parent directory to the system path:
import sys
from pathlib import Path
parent_dir = Path('..').resolve() 
sys.path.append(str(parent_dir)) 

# import:
import numpy as np
import os
import matplotlib.pyplot as plt
from evaluation_trajectories import evaluation2D, evaluation2D_partial, evaluation2D_p, evaluation2D_partial_p

# seed:
np.random.seed(666)

# %%
# select the ODE:
ode_name_09 = 'SelkovODE_rho_09'
init_high_09 = [0.05, 0.05, 0.9]
init_low_09 = [0.05, 0.05, 0.9]

ode_name_06 = 'SelkovODE_rho_06'
init_high_06 = [0.05, 0.05, 0.6]
init_low_06 = [0.05, 0.05, 0.6]

ode_name_04 = 'SelkovODE_rho_04'
init_high_04 = [0.05, 0.05, 0.4]
init_low_04 = [0.05, 0.05, 0.4]

ode_name_03 = 'SelkovODE_rho_03'
init_high_03 = [0.05, 0.05, 0.3]
init_low_03 = [0.05, 0.05, 0.3]

ode_param=None
x_id = 0
freq = 10
n_sample = 50 
noise_ratio = 0.01
alg = 'diff'
seed = 0
n_seed = 5

# %% [markdown]
# ##### DEV: b=0.6, freq=10, T=15, scaled_noise, p_c=0.01 -> KO
# !!!DO NOT RUN!!!

# %%
# Partial Reconstruction: Equation 1 only
# evaluation: 
xt_true, est_trajectories, rmse = evaluation2D_partial_p(ode_name_06, ode_param, x_id, freq, n_sample, noise_ratio, alg, seed, n_seed, init_high_06, init_low_06)
print(rmse)

# plot:
plt.figure(figsize=(12, 8))

for i in range(np.shape(est_trajectories)[0]):
    plt.plot(est_trajectories[i][:, 0, 0], est_trajectories[i][:, 0, 1], color='blue', linewidth=0.5, alpha=0.7)

plt.plot(xt_true[:, 0, 0], xt_true[:, 0, 1], color='red', linewidth=1.0, label='Correct Trajectory')

plt.scatter(xt_true[:, 0, 0][0], xt_true[:, 0, 1][0], color='green', label='Start')
plt.scatter(xt_true[:, 0, 0][-1], xt_true[:, 0, 1][-1], color='red', label='End')

plt.title('Partial Reconstruction: Equation 1 only')
plt.legend()
plt.grid(True)
# Out:
# 5
# 0.0
# [0.09964745261419894, 0.21623943623459846, 0.1776272881682917, 0.15579879096196275, 0.09019832715365608]
# 0.14790225902654158

# %%
# Partial Reconstruction: Equation 2 only
# evaluation: 
xt_true, est_trajectories, rmse = evaluation2D_partial_p(ode_name_06, ode_param, 1, freq, n_sample, noise_ratio, alg, seed, n_seed, init_high_06, init_low_06)
print(rmse)

# plot:
plt.figure(figsize=(12, 8))

for i in range(np.shape(est_trajectories)[0]):
    plt.plot(est_trajectories[i][:, 0, 0], est_trajectories[i][:, 0, 1], color='blue', linewidth=0.5, alpha=0.7)

plt.plot(xt_true[:, 0, 0], xt_true[:, 0, 1], color='red', linewidth=1.0, label='Correct Trajectory')

plt.scatter(xt_true[:, 0, 0][0], xt_true[:, 0, 1][0], color='green', label='Start')
plt.scatter(xt_true[:, 0, 0][-1], xt_true[:, 0, 1][-1], color='red', label='End')

plt.title('Partial Reconstruction: Equation 2 only')
plt.legend()
plt.grid(True)
# Out:
# 3
# 0.0
# Skipping this seed
# [1.1681613492921905, 1.1710427786523248]
# 1.1696020639722575
# /Users/grgromano/miniconda3/envs/d-code_grg/lib/python3.12/site-packages/scipy/integrate/_ode.py:431: UserWarning: lsoda: Excess work done on this call (perhaps wrong Dfun type).
#   self._y, self.t = mth(self.f, self.jac or (lambda: None),

# %%
# Total Reconstruction:
# evaluation: 
xt_true, est_trajectories, rmse = evaluation2D_p(ode_name_06, ode_param, x_id, freq, n_sample, noise_ratio, alg, seed, n_seed, init_high_06, init_low_06)
print(rmse)

# plot:
plt.figure(figsize=(12, 8))

for i in range(np.shape(est_trajectories)[0]):
    plt.plot(est_trajectories[i][:, 0, 0], est_trajectories[i][:, 0, 1], color='blue', linewidth=0.5, alpha=0.7)

plt.plot(xt_true[:, 0, 0], xt_true[:, 0, 1], color='red', linewidth=1.0, label='Correct Trajectory')

plt.scatter(xt_true[:, 0, 0][0], xt_true[:, 0, 1][0], color='green', label='Start')
plt.scatter(xt_true[:, 0, 0][-1], xt_true[:, 0, 1][-1], color='red', label='End')

plt.title('Total Reconstruction')
plt.legend()
plt.grid(True)
# Out:
# 3
# 0.0
# 0.0
# Skipping this seed
# [1.2853715924120568, 1.247483051861351]
# 1.266427322136704
# /Users/grgromano/miniconda3/envs/d-code_grg/lib/python3.12/site-packages/scipy/integrate/_ode.py:431: UserWarning: lsoda: Excess work done on this call (perhaps wrong Dfun type).
#   self._y, self.t = mth(self.f, self.jac or (lambda: None),

# %% [markdown]
# ##### b=0.6, freq=10, T=15, scaled_noise, p_c=0.001

# %%
# Partial Reconstruction: Equation 1 only
# evaluation: 
xt_true, est_trajectories, rmse = evaluation2D_partial_p(ode_name_06, ode_param, x_id, freq, n_sample, noise_ratio, alg, seed, n_seed, init_high_06, init_low_06)
print('RMSE on test-case 0: ', rmse)

# plot:
plt.figure(figsize=(8, 6))

for i in range(np.shape(est_trajectories)[0]):
    plt.plot(est_trajectories[i][:, 0, 0], est_trajectories[i][:, 0, 1], color='blue', linewidth=0.5, alpha=0.7)

plt.plot(xt_true[:, 0, 0], xt_true[:, 0, 1], color='red', linewidth=1.0, label='Correct Trajectory')

plt.scatter(xt_true[:, 0, 0][0], xt_true[:, 0, 1][0], color='green', label='Start')
plt.scatter(xt_true[:, 0, 0][-1], xt_true[:, 0, 1][-1], color='red', label='End')

plt.title('Partial Reconstruction: Equation 1 only')
plt.legend()
plt.grid(True)
# Out:
# 5
# 0.8
# [0.005629720591332418, 0.014642639009049874, 0.0034935152701037323, 0.00823105756249487, 0.00034113057115648423]
# RMSE on test-case 0:  0.006467612600827476

# %%
# Partial Reconstruction: Equation 2 only
# evaluation: 
xt_true, est_trajectories, rmse = evaluation2D_partial_p(ode_name_06, ode_param, 1, freq, n_sample, noise_ratio, alg, seed, n_seed, init_high_06, init_low_06)
print('RMSE on test-case 0: ', rmse)

# plot:
plt.figure(figsize=(8, 6))

for i in range(np.shape(est_trajectories)[0]):
    plt.plot(est_trajectories[i][:, 0, 0], est_trajectories[i][:, 0, 1], color='blue', linewidth=0.5, alpha=0.7)

plt.plot(xt_true[:, 0, 0], xt_true[:, 0, 1], color='red', linewidth=1.0, label='Correct Trajectory')

plt.scatter(xt_true[:, 0, 0][0], xt_true[:, 0, 1][0], color='green', label='Start')
plt.scatter(xt_true[:, 0, 0][-1], xt_true[:, 0, 1][-1], color='red', label='End')

plt.title('Partial Reconstruction: Equation 2 only')
plt.legend()
plt.grid(True)
# Out:
# 5
# 0.2
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1188347494142D+02   r2 =  0.7559370518026D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1188347494142D+02   r2 =  0.7559370518026D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1188347494142D+02   r2 =  0.7559370518026D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1188347494142D+02   r2 =  0.5890737578448D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1188347494142D+02   r2 =  0.5890737578448D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1188347494142D+02   r2 =  0.4862887596231D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1188347494142D+02   r2 =  0.4862887596231D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1188347494142D+02   r2 =  0.4862887596231D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1188347494142D+02   r2 =  0.3789468272160D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1188347494142D+02   r2 =  0.3789468272160D-15
#  lsoda--  above warning has been issued i1 times.
#        it will not be issued again for this problem
#       in above message,  i1 =        10
# Skipping this seed
# [0.024001487130090787, 1.0606169076463887, 1.0561397751824424, 1.018363301566645]
# RMSE on test-case 0:  0.7897803678813917
# /Users/grgromano/miniconda3/envs/d-code_gege/lib/python3.12/site-packages/scipy/integrate/_ode.py:431: UserWarning: lsoda: Excess work done on this call (perhaps wrong Dfun type).
#   self._y, self.t = mth(self.f, self.jac or (lambda: None),

# %%
# Total Reconstruction:
# evaluation: 
xt_true6, est_trajectories6, rmse6 = evaluation2D_p(ode_name_06, ode_param, x_id, freq, n_sample, noise_ratio, alg, seed, n_seed, init_high_06, init_low_06)
print('RMSE on test-case 0: ', rmse6)

# plot:
plt.figure(figsize=(8, 6))

for i in range(np.shape(est_trajectories6)[0]):
    plt.plot(est_trajectories6[i][:, 0, 0], est_trajectories6[i][:, 0, 1], color='blue', linewidth=0.5, alpha=0.7)

plt.plot(xt_true6[:, 0, 0], xt_true6[:, 0, 1], color='red', linewidth=1.0, label='Correct Trajectory')

plt.scatter(xt_true6[:, 0, 0][0], xt_true6[:, 0, 1][0], color='green', label='Start')
plt.scatter(xt_true6[:, 0, 0][-1], xt_true6[:, 0, 1][-1], color='red', label='End')

plt.title('Total Reconstruction')
plt.legend()
plt.grid(True)
# Out:
# 5
# 0.8
# 0.2
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1188123504552D+02   r2 =  0.7556896313916D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1188123504552D+02   r2 =  0.7556896313916D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1188123504552D+02   r2 =  0.7556896313916D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1188123504552D+02   r2 =  0.5888809522792D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1188123504552D+02   r2 =  0.5888809522792D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1188123504552D+02   r2 =  0.4861295958882D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1188123504552D+02   r2 =  0.4861295958882D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1188123504552D+02   r2 =  0.4861295958882D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1188123504552D+02   r2 =  0.3788227968107D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1188123504552D+02   r2 =  0.3788227968107D-15
#  lsoda--  above warning has been issued i1 times.
#        it will not be issued again for this problem
#       in above message,  i1 =        10
# Skipping this seed
# [0.028782170198405663, 1.0621036216770885, 1.0565727928602406, 1.0173201040737665]
# RMSE on test-case 0:  0.7911946722023753
# /Users/grgromano/miniconda3/envs/d-code_gege/lib/python3.12/site-packages/scipy/integrate/_ode.py:431: UserWarning: lsoda: Excess work done on this call (perhaps wrong Dfun type).
#   self._y, self.t = mth(self.f, self.jac or (lambda: None),

# %%
# RMSE:

N = 10
a, b = 0.0, 0.1  # first input interval
c, d = 0.0, 0.1  # second input interval
e, f = 0.55, 0.65  # third input interval
init_point = np.empty((N, 3))
init_point[:, 0] = np.random.uniform(a, b, N) 
init_point[:, 1] = np.random.uniform(c, d, N) 
init_point[:, 2] = np.random.uniform(e, f, N) 

RMSE_rho = evaluation2D_p(ode_name_06, ode_param, x_id, freq, n_sample, noise_ratio, alg, seed, n_seed, init_high_06, init_low_06, N, init_point)
print('RMSE (overall): ', RMSE_rho)
print('scaled RMSE (overall): ', RMSE_rho/0.7211417)
# Out:
# 5
# 0.8
# 0.2
# /Users/grgromano/miniconda3/envs/d-code_gege/lib/python3.12/site-packages/scipy/integrate/_ode.py:431: UserWarning: lsoda: Excess work done on this call (perhaps wrong Dfun type).
#   self._y, self.t = mth(self.f, self.jac or (lambda: None),
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1209016258944D+02   r2 =  0.7723707017502D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1209016258944D+02   r2 =  0.7723707017502D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1209016258944D+02   r2 =  0.6376029916195D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1209016258944D+02   r2 =  0.6376029916195D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1209016258944D+02   r2 =  0.6376029916195D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1209016258944D+02   r2 =  0.4968604059783D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1209016258944D+02   r2 =  0.4968604059783D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1209016258944D+02   r2 =  0.4101653271573D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1209016258944D+02   r2 =  0.4101653271573D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1209016258944D+02   r2 =  0.4101653271573D-15
#  lsoda--  above warning has been issued i1 times.
#        it will not be issued again for this problem
#       in above message,  i1 =        10
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1166703245060D+02   r2 =  0.7621117550695D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1166703245060D+02   r2 =  0.7621117550695D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1166703245060D+02   r2 =  0.6291340853540D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1166703245060D+02   r2 =  0.6291340853540D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1166703245060D+02   r2 =  0.6291340853540D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1166703245060D+02   r2 =  0.4902609008832D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1166703245060D+02   r2 =  0.4902609008832D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1166703245060D+02   r2 =  0.4047173419135D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1166703245060D+02   r2 =  0.4047173419135D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1166703245060D+02   r2 =  0.4047173419135D-15
#  lsoda--  above warning has been issued i1 times.
#        it will not be issued again for this problem
#       in above message,  i1 =        10
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1445125011078D+02   r2 =  0.7410260073306D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1445125011078D+02   r2 =  0.7410260073306D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1445125011078D+02   r2 =  0.6117275009353D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1445125011078D+02   r2 =  0.6117275009353D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1445125011078D+02   r2 =  0.6117275009353D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1445125011078D+02   r2 =  0.4766965940927D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1445125011078D+02   r2 =  0.4766965940927D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1445125011078D+02   r2 =  0.3935198138752D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1445125011078D+02   r2 =  0.3935198138752D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1445125011078D+02   r2 =  0.3935198138752D-15
#  lsoda--  above warning has been issued i1 times.
#        it will not be issued again for this problem
#       in above message,  i1 =        10
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1235019483311D+02   r2 =  0.7770361349364D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1235019483311D+02   r2 =  0.7770361349364D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1235019483311D+02   r2 =  0.7770361349364D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1235019483311D+02   r2 =  0.6055154921418D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1235019483311D+02   r2 =  0.6055154921418D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1235019483311D+02   r2 =  0.4998616449423D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1235019483311D+02   r2 =  0.4998616449423D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1235019483311D+02   r2 =  0.4998616449423D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1235019483311D+02   r2 =  0.3895236742307D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1235019483311D+02   r2 =  0.3895236742307D-15
#  lsoda--  above warning has been issued i1 times.
#        it will not be issued again for this problem
#       in above message,  i1 =        10
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.9553751151219D+01   r2 =  0.7338637986276D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.9553751151219D+01   r2 =  0.7338637986276D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.9553751151219D+01   r2 =  0.7338637986276D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.9553751151219D+01   r2 =  0.5718728889297D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.9553751151219D+01   r2 =  0.5718728889297D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.9553751151219D+01   r2 =  0.4720891979038D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.9553751151219D+01   r2 =  0.4720891979038D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.9553751151219D+01   r2 =  0.4720891979038D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.9553751151219D+01   r2 =  0.3678816344984D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.9553751151219D+01   r2 =  0.3678816344984D-15
#  lsoda--  above warning has been issued i1 times.
#        it will not be issued again for this problem
#       in above message,  i1 =        10
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1032327759246D+02   r2 =  0.8506623509702D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1032327759246D+02   r2 =  0.8506623509702D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1032327759246D+02   r2 =  0.7022338606451D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1032327759246D+02   r2 =  0.7022338606451D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1032327759246D+02   r2 =  0.7022338606451D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1032327759246D+02   r2 =  0.5472248493305D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1032327759246D+02   r2 =  0.5472248493305D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1032327759246D+02   r2 =  0.4517418909236D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1032327759246D+02   r2 =  0.4517418909236D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1032327759246D+02   r2 =  0.4517418909236D-15
#  lsoda--  above warning has been issued i1 times.
#        it will not be issued again for this problem
#       in above message,  i1 =        10
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1439052378096D+02   r2 =  0.8697271629563D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1439052378096D+02   r2 =  0.8697271629563D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1439052378096D+02   r2 =  0.8697271629563D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1439052378096D+02   r2 =  0.6777461783449D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1439052378096D+02   r2 =  0.6777461783449D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1439052378096D+02   r2 =  0.5594891028483D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1439052378096D+02   r2 =  0.5594891028483D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1439052378096D+02   r2 =  0.5594891028483D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1439052378096D+02   r2 =  0.4359891445281D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1439052378096D+02   r2 =  0.4359891445281D-15
#  lsoda--  above warning has been issued i1 times.
#        it will not be issued again for this problem
#       in above message,  i1 =        10
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1053613991415D+02   r2 =  0.8808485222080D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1053613991415D+02   r2 =  0.8808485222080D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1053613991415D+02   r2 =  0.7271529739451D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1053613991415D+02   r2 =  0.7271529739451D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1053613991415D+02   r2 =  0.7271529739451D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1053613991415D+02   r2 =  0.5666433917005D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1053613991415D+02   r2 =  0.5666433917005D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1053613991415D+02   r2 =  0.4677721736113D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1053613991415D+02   r2 =  0.4677721736113D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1053613991415D+02   r2 =  0.4677721736113D-15
#  lsoda--  above warning has been issued i1 times.
#        it will not be issued again for this problem
#       in above message,  i1 =        10
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1155180369288D+02   r2 =  0.8175319909339D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1155180369288D+02   r2 =  0.8175319909339D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1155180369288D+02   r2 =  0.8175319909339D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1155180369288D+02   r2 =  0.6370724133920D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1155180369288D+02   r2 =  0.6370724133920D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1155180369288D+02   r2 =  0.5259123319100D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1155180369288D+02   r2 =  0.5259123319100D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1155180369288D+02   r2 =  0.5259123319100D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1155180369288D+02   r2 =  0.4098240101101D-15
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1155180369288D+02   r2 =  0.4098240101101D-15
#  lsoda--  above warning has been issued i1 times.
#        it will not be issued again for this problem
#       in above message,  i1 =        10
# Skipping this seed
# [0.029183664661819386, 1.052960028756286, 1.0444633740545526, 1.0132967444088312]
# RMSE (overall):  0.7849759529703721
# scaled RMSE (overall):  1.0885183216701686

# %% [markdown]
# ##### b=0.9, freq=10, T=15, scaled_noise, p_c=0.001

# %%
# Partial Reconstruction: Equation 1 only
# evaluation: 
xt_true, est_trajectories, rmse = evaluation2D_partial_p(ode_name_09, ode_param, x_id, freq, n_sample, noise_ratio, alg, seed, n_seed, init_high_09, init_low_09)
print('RMSE on test-case 0: ', rmse)

# plot:
plt.figure(figsize=(8, 6))

for i in range(np.shape(est_trajectories)[0]):
    plt.plot(est_trajectories[i][:, 0, 0], est_trajectories[i][:, 0, 1], color='blue', linewidth=0.5, alpha=0.7)

plt.plot(xt_true[:, 0, 0], xt_true[:, 0, 1], color='red', linewidth=1.0, label='Correct Trajectory')

plt.scatter(xt_true[:, 0, 0][0], xt_true[:, 0, 1][0], color='green', label='Start')
plt.scatter(xt_true[:, 0, 0][-1], xt_true[:, 0, 1][-1], color='red', label='End')

plt.title('Partial Reconstruction: Equation 1 only')
plt.legend()
plt.grid(True)
# Out:
# 5
# 0.6
# [0.003941149372860089, 0.027371099533574517, 0.03654330309344889, 0.014235716324968712, 0.0007813254530469906]
# RMSE on test-case 0:  0.016574518755579838

# %%
# Partial Reconstruction: Equation 2 only
# evaluation: 
xt_true, est_trajectories, rmse = evaluation2D_partial_p(ode_name_09, ode_param, 1, freq, n_sample, noise_ratio, alg, seed, n_seed, init_high_09, init_low_09)
print('RMSE on test-case 0: ', rmse)

# plot:
plt.figure(figsize=(8, 6))

for i in range(np.shape(est_trajectories)[0]):
    plt.plot(est_trajectories[i][:, 0, 0], est_trajectories[i][:, 0, 1], color='blue', linewidth=0.5, alpha=0.7)

plt.plot(xt_true[:, 0, 0], xt_true[:, 0, 1], color='red', linewidth=1.0, label='Correct Trajectory')

plt.scatter(xt_true[:, 0, 0][0], xt_true[:, 0, 1][0], color='green', label='Start')
plt.scatter(xt_true[:, 0, 0][-1], xt_true[:, 0, 1][-1], color='red', label='End')

plt.title('Partial Reconstruction: Equation 2 only')
plt.legend()
plt.grid(True)
# Out:
# 5
# 0.8
# [0.045620947130024354, 0.01345994330280512, 0.03119358381933542, 0.006145720221799029, 0.027802221880477283]
# RMSE on test-case 0:  0.02484448327088824

# %%
# Total Reconstruction:
# evaluation: 
xt_true9, est_trajectories9, rmse9 = evaluation2D_p(ode_name_09, ode_param, x_id, freq, n_sample, noise_ratio, alg, seed, n_seed, init_high_09, init_low_09)
print('RMSE on test-case 0: ', rmse9)

# plot:
plt.figure(figsize=(8, 6))

for i in range(np.shape(est_trajectories9)[0]):
    plt.plot(est_trajectories9[i][:, 0, 0], est_trajectories9[i][:, 0, 1], color='blue', linewidth=0.5, alpha=0.7)

plt.plot(xt_true9[:, 0, 0], xt_true9[:, 0, 1], color='red', linewidth=1.0, label='Correct Trajectory')

plt.scatter(xt_true9[:, 0, 0][0], xt_true9[:, 0, 1][0], color='green', label='Start')
plt.scatter(xt_true9[:, 0, 0][-1], xt_true9[:, 0, 1][-1], color='red', label='End')

plt.title('Total Reconstruction')
plt.legend()
plt.grid(True)
# Out:
# 5
# 0.6
# 0.8
# [0.04219908074865657, 0.038282056272843645, 0.03286168652863565, 0.020007070793714894, 0.02708808205641978]
# RMSE on test-case 0:  0.0320875952800541

# %%
# RMSE:

N = 50
a, b = 0.0, 0.1  # first input interval
c, d = 0.0, 0.1  # second input interval
e, f = 0.85, 0.95  # third input interval
init_point = np.empty((N, 3))
init_point[:, 0] = np.random.uniform(a, b, N) 
init_point[:, 1] = np.random.uniform(c, d, N) 
init_point[:, 2] = np.random.uniform(e, f, N)   

RMSE_rho = evaluation2D_p(ode_name_09, ode_param, x_id, freq, n_sample, noise_ratio, alg, seed, n_seed, init_high_09, init_low_09, N, init_point)
print('RMSE (overall): ', RMSE_rho)
print('scaled RMSE (overall): ', RMSE_rho/1.04538449)
# Out:
# 5
# 0.6
# 0.8
# [0.042525621876433065, 0.039105946024930095, 0.04094139242520213, 0.020289443104863355, 0.027439804296330764]
# RMSE (overall):  0.03406044154555188
# scaled RMSE (overall):  0.03258173607066992

# %% [markdown]
# ##### b=0.4, freq=10, T=15, scaled_noise, p_c=0.001

# %%
# Partial Reconstruction: Equation 1 only
# evaluation: 
xt_true, est_trajectories, rmse = evaluation2D_partial_p(ode_name_04, ode_param, x_id, freq, n_sample, noise_ratio, alg, seed, n_seed, init_high_04, init_low_04)
print('RMSE on test-case 0: ', rmse)

# plot:
plt.figure(figsize=(8, 6))

for i in range(np.shape(est_trajectories)[0]):
    plt.plot(est_trajectories[i][:, 0, 0], est_trajectories[i][:, 0, 1], color='blue', linewidth=0.5, alpha=0.7)

plt.plot(xt_true[:, 0, 0], xt_true[:, 0, 1], color='red', linewidth=1.0, label='Correct Trajectory')

plt.scatter(xt_true[:, 0, 0][0], xt_true[:, 0, 1][0], color='green', label='Start')
plt.scatter(xt_true[:, 0, 0][-1], xt_true[:, 0, 1][-1], color='red', label='End')

plt.title('Partial Reconstruction: Equation 1 only')
plt.legend()
plt.grid(True)
# Out:
# 5
# 0.0
# [0.012025401797965664, 0.020075260136172272, 0.08156370217254859, 0.07013060047644316, 0.03558281210600685]
# RMSE on test-case 0:  0.04387555533782731

# %%
# Partial Reconstruction: Equation 2 only
# evaluation: 
xt_true, est_trajectories, rmse = evaluation2D_partial_p(ode_name_04, ode_param, 1, freq, n_sample, noise_ratio, alg, seed, n_seed, init_high_04, init_low_04)
print('RMSE on test-case 0: ', rmse)

# plot:
plt.figure(figsize=(8, 6))

for i in range(np.shape(est_trajectories)[0]):
    plt.plot(est_trajectories[i][:, 0, 0], est_trajectories[i][:, 0, 1], color='blue', linewidth=0.5, alpha=0.7)

plt.plot(xt_true[:, 0, 0], xt_true[:, 0, 1], color='red', linewidth=1.0, label='Correct Trajectory')

plt.scatter(xt_true[:, 0, 0][0], xt_true[:, 0, 1][0], color='green', label='Start')
plt.scatter(xt_true[:, 0, 0][-1], xt_true[:, 0, 1][-1], color='red', label='End')

plt.title('Partial Reconstruction: Equation 2 only')
plt.legend()
plt.grid(True)
# Out:
# 5
# 0.0
# [0.44989907964517367, 0.3848473835256583, 0.45449510018900285, 0.47101980356758394, 0.4448902347884612]
# RMSE on test-case 0:  0.441030320343176

# %%
# Total Reconstruction:
# evaluation: 
xt_true4, est_trajectories4, rmse4 = evaluation2D_p(ode_name_04, ode_param, x_id, freq, n_sample, noise_ratio, alg, seed, n_seed, init_high_04, init_low_04)
print('RMSE on test-case 0: ', rmse4)

# plot:
plt.figure(figsize=(8, 6))

for i in range(np.shape(est_trajectories4)[0]):
    plt.plot(est_trajectories4[i][:, 0, 0], est_trajectories4[i][:, 0, 1], color='blue', linewidth=0.5, alpha=0.7)

plt.plot(xt_true4[:, 0, 0], xt_true4[:, 0, 1], color='red', linewidth=1.0, label='Correct Trajectory')

plt.scatter(xt_true4[:, 0, 0][0], xt_true4[:, 0, 1][0], color='green', label='Start')
plt.scatter(xt_true4[:, 0, 0][-1], xt_true4[:, 0, 1][-1], color='red', label='End')

plt.title('Total Reconstruction')
plt.legend()
plt.grid(True)
# Out:
# 5
# 0.0
# 0.0
# [0.41696289098147354, 0.36901127080540314, 0.3915064922525746, 0.47401747466436994, 0.45635073566262496]
# RMSE on test-case 0:  0.42156977287328923

# %%
# RMSE:

N = 50
a, b = 0.0, 0.1  # first input interval
c, d = 0.0, 0.1  # second input interval
e, f = 0.35, 0.45  # third input interval
init_point = np.empty((N, 3))
init_point[:, 0] = np.random.uniform(a, b, N) 
init_point[:, 1] = np.random.uniform(c, d, N) 
init_point[:, 2] = np.random.uniform(e, f, N)           

RMSE_rho = evaluation2D_p(ode_name_04, ode_param, x_id, freq, n_sample, noise_ratio, alg, seed, n_seed, init_high_04, init_low_04, N, init_point)
print('RMSE (overall): ', RMSE_rho)
print('scaled RMSE (overall): ', RMSE_rho/0.3327572)
# Out:
# 5
# 0.0
# 0.0
# [0.5025452685799674, 0.48913588491740667, 0.5201081832163754, 0.5722998138398224, 0.5512141276615994]
# RMSE (overall):  0.5270606556430343
# scaled RMSE (overall):  1.5839196135892306

# %% [markdown]
# ##### DEV: b=0.4, freq=10, T=15, scaled_noise, p_c=0.001, scaled window
#
# !!!DO NOT RUN!!!

# %%
# Partial Reconstruction: Equation 1 only
# evaluation: 
xt_true, est_trajectories, rmse = evaluation2D_partial_p(ode_name_04, ode_param, x_id, freq, n_sample, noise_ratio, alg, seed, n_seed, init_high_04, init_low_04)
print(rmse)

# plot:
plt.figure(figsize=(12, 8))

for i in range(np.shape(est_trajectories)[0]):
    plt.plot(est_trajectories[i][:, 0, 0], est_trajectories[i][:, 0, 1], color='blue', linewidth=0.5, alpha=0.7)

plt.plot(xt_true[:, 0, 0], xt_true[:, 0, 1], color='red', linewidth=1.0, label='Correct Trajectory')

plt.scatter(xt_true[:, 0, 0][0], xt_true[:, 0, 1][0], color='green', label='Start')
plt.scatter(xt_true[:, 0, 0][-1], xt_true[:, 0, 1][-1], color='red', label='End')

plt.title('Partial Reconstruction: Equation 1 only')
plt.legend()
plt.grid(True)
# Out:
# 3
# 0.0
# [0.03884783217546092, 0.043288725771507025, 0.07283085222705292]
# 0.051655803391340294

# %%
# Partial Reconstruction: Equation 2 only
# evaluation: 
xt_true, est_trajectories, rmse = evaluation2D_partial_p(ode_name_04, ode_param, 1, freq, n_sample, noise_ratio, alg, seed, n_seed, init_high_04, init_low_04)
print(rmse)

# plot:
plt.figure(figsize=(12, 8))

for i in range(np.shape(est_trajectories)[0]):
    plt.plot(est_trajectories[i][:, 0, 0], est_trajectories[i][:, 0, 1], color='blue', linewidth=0.5, alpha=0.7)

plt.plot(xt_true[:, 0, 0], xt_true[:, 0, 1], color='red', linewidth=1.0, label='Correct Trajectory')

plt.scatter(xt_true[:, 0, 0][0], xt_true[:, 0, 1][0], color='green', label='Start')
plt.scatter(xt_true[:, 0, 0][-1], xt_true[:, 0, 1][-1], color='red', label='End')

plt.title('Partial Reconstruction: Equation 2 only')
plt.legend()
plt.grid(True)
# Out:
# 3
# 0.0
# [0.45209496642432445, 0.4265843228496858, 0.10732420328753839]
# 0.32866783085384954

# %%
# Total Reconstruction:
# evaluation: 
xt_true4, est_trajectories4, rmse4 = evaluation2D_p(ode_name_04, ode_param, x_id, freq, n_sample, noise_ratio, alg, seed, n_seed, init_high_04, init_low_04)
print(rmse4)

# plot:
plt.figure(figsize=(12, 8))

for i in range(np.shape(est_trajectories4)[0]):
    plt.plot(est_trajectories4[i][:, 0, 0], est_trajectories4[i][:, 0, 1], color='blue', linewidth=0.5, alpha=0.7)

plt.plot(xt_true4[:, 0, 0], xt_true4[:, 0, 1], color='red', linewidth=1.0, label='Correct Trajectory')

plt.scatter(xt_true4[:, 0, 0][0], xt_true4[:, 0, 1][0], color='green', label='Start')
plt.scatter(xt_true4[:, 0, 0][-1], xt_true4[:, 0, 1][-1], color='red', label='End')

plt.title('Total Reconstruction')
plt.legend()
plt.grid(True)
# Out:
# 3
# 0.0
# 0.0
# [0.43790309117775306, 0.3462704432080609, 0.10907182771342097]
# 0.2977484540330783

# %% [markdown]
# ##### plot x report:

# %%
fig, axs = plt.subplots(1, 3, figsize=(16, 4))

for i in range(np.shape(est_trajectories9)[0]):
    axs[0].plot(est_trajectories9[i][:, 0, 0], est_trajectories9[i][:, 0, 1], color='blue', linewidth=0.5, alpha=0.7)
axs[0].plot(xt_true9[:, 0, 0], xt_true9[:, 0, 1], color='red', linewidth=1.0, label='Correct Trajectory')
axs[0].scatter(xt_true9[:, 0, 0][0], xt_true9[:, 0, 1][0], color='green', label='Start')
axs[0].scatter(xt_true9[:, 0, 0][-1], xt_true9[:, 0, 1][-1], color='red', label='End')
axs[0].set_xlabel('$x_1$')
axs[0].set_ylabel('$x_2$')
axs[0].set_title(r'$\rho \simeq 0.9$ - Estimated Trajectories')
axs[0].legend()
axs[0].grid(True) 

for i in range(np.shape(est_trajectories6)[0]):
    axs[1].plot(est_trajectories6[i][:, 0, 0], est_trajectories6[i][:, 0, 1], color='blue', linewidth=0.5, alpha=0.7)
axs[1].plot(xt_true6[:, 0, 0], xt_true6[:, 0, 1], color='red', linewidth=1.0, label='Correct Trajectory')
axs[1].scatter(xt_true6[:, 0, 0][0], xt_true6[:, 0, 1][0], color='green', label='Start')
axs[1].scatter(xt_true6[:, 0, 0][-1], xt_true6[:, 0, 1][-1], color='red', label='End')
axs[1].set_xlabel('$x_1$')
axs[1].set_ylabel('$x_2$')
axs[1].set_title(r'$\rho \simeq 0.6$ - Estimated Trajectories')
axs[1].legend()
axs[1].grid(True) 

for i in range(np.shape(est_trajectories4)[0]):
    axs[2].plot(est_trajectories4[i][:, 0, 0], est_trajectories4[i][:, 0, 1], color='blue', linewidth=0.5, alpha=0.7)
axs[2].plot(xt_true4[:, 0, 0], xt_true4[:, 0, 1], color='red', linewidth=1.0, label='Correct Trajectory')
axs[2].scatter(xt_true4[:, 0, 0][0], xt_true4[:, 0, 1][0], color='green', label='Start')
axs[2].scatter(xt_true4[:, 0, 0][-1], xt_true4[:, 0, 1][-1], color='red', label='End')
axs[2].set_xlabel('$x_1$')
axs[2].set_ylabel('$x_2$')
axs[2].set_title(r'$\rho \simeq 0.4$ - Estimated Trajectories')
axs[2].legend()
axs[2].grid(True)

# %%
rmse9 = round(rmse9, 4)
rmse6 = round(rmse6, 4)
rmse4 = round(rmse4, 4)

fig, axs = plt.subplots(1, 3, figsize=(16, 0.5))

axs[0].text(0.5, 0.5, f'RMSE on trajectories: {rmse9}', ha='center', va='center', fontsize=12)
axs[0].axis('off')

axs[1].text(0.5, 0.5, f'RMSE on trajectories: {rmse6}', ha='center', va='center', fontsize=12)
axs[1].axis('off')

axs[2].text(0.5, 0.5, f'RMSE on trajectories: {rmse4}', ha='center', va='center', fontsize=12)
axs[2].axis('off')

plt.show()
