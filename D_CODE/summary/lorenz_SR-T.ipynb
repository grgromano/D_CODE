# %% [markdown]
# ### Lorenz Model - SR-T performance:

# %%
# add the parent directory to the system path:
import sys
from pathlib import Path
parent_dir = Path('..').resolve() 
sys.path.append(str(parent_dir)) 

# import:
import numpy as np
import os
import matplotlib.pyplot as plt
import equations
from mpl_toolkits.mplot3d import Axes3D
from evaluation_trajectories import evaluation3D, evaluation3D_partial, evaluation3D_partial_p

# %% [markdown]
# ### Standard:

# %%
# select the ODE:
ode_name = 'Lorenz'
init_high = [5, 5, 5]
init_low = [5, 5, 5]

ode_param=None
n_sample = 50 
noise_ratio = 0.01 # RMK. con 0.09 funziona meglio  
alg = 'diff'
seed = 0
n_seed = 5

# %%
# evaluation:
x_id = 0
freq = 25
xt_true, est_trajectories, rmse = evaluation3D_partial(ode_name, ode_param, x_id, freq, n_sample, noise_ratio, alg, seed, n_seed, init_high, init_low)
print(rmse)

# 3D-plot:
fig, axs = plt.subplots(1, 2, figsize=(12, 6), subplot_kw={'projection': '3d'})

i_best = 3 # best trajectory:
axs[0].plot(est_trajectories[i_best][:, 0, 0], est_trajectories[i_best][:, 0, 1], est_trajectories[i_best][:, 0, 2], color='blue', linewidth=1.0, alpha=0.7)
axs[0].plot(xt_true[:, 0, 0], xt_true[:, 0, 1], xt_true[:, 0, 2], color='red', linewidth=1.0, label='Correct Trajectory')
axs[0].scatter(xt_true[:, 0, 0][0], xt_true[:, 0, 1][0], xt_true[:, 0, 2][0], color='green', label='Start')
axs[0].scatter(xt_true[:, 0, 0][-1], xt_true[:, 0, 1][-1], xt_true[:, 0, 2][-1], color='red', label='End')
axs[0].set_title('Partial Reconstruction (1) - best-case s.')
axs[0].legend()
axs[0].grid(True)

i_worst = 4 # worst trajectory:
axs[1].plot(est_trajectories[i_worst][:, 0, 0], est_trajectories[i_worst][:, 0, 1], est_trajectories[i_worst][:, 0, 2], color='blue', linewidth=1.0, alpha=0.7)
axs[1].plot(xt_true[:, 0, 0], xt_true[:, 0, 1], xt_true[:, 0, 2], color='red', linewidth=1.0, label='Correct Trajectory')
axs[1].scatter(xt_true[:, 0, 0][0], xt_true[:, 0, 1][0], xt_true[:, 0, 2][0], color='green', label='Start')
axs[1].scatter(xt_true[:, 0, 0][-1], xt_true[:, 0, 1][-1], xt_true[:, 0, 2][-1], color='red', label='End')
axs[1].set_title('Partial Reconstruction (1) - worst-case s.')
axs[1].legend()
axs[1].grid(True)
# Out:
# 5
# 1.0
# [10.18937027367229, 10.457770741636159, 9.488514283709515, 9.437333120082565, 10.689108784410843]
# 10.052419440702273

# %%
# evaluation:
x_id = 1
freq = 50
xt_true, est_trajectories, rmse = evaluation3D_partial(ode_name, ode_param, x_id, freq, n_sample, noise_ratio, alg, seed, n_seed, init_high, init_low)
print(rmse)

# 3D-plot:
fig, axs = plt.subplots(1, 2, figsize=(12, 6), subplot_kw={'projection': '3d'})

i_best = 2 # best trajectory:
axs[0].plot(est_trajectories[i_best][:, 0, 0], est_trajectories[i_best][:, 0, 1], est_trajectories[i_best][:, 0, 2], color='blue', linewidth=1.0, alpha=0.7)
axs[0].plot(xt_true[:, 0, 0], xt_true[:, 0, 1], xt_true[:, 0, 2], color='red', linewidth=1.0, label='Correct Trajectory')
axs[0].scatter(xt_true[:, 0, 0][0], xt_true[:, 0, 1][0], xt_true[:, 0, 2][0], color='green', label='Start')
axs[0].scatter(xt_true[:, 0, 0][-1], xt_true[:, 0, 1][-1], xt_true[:, 0, 2][-1], color='red', label='End')
axs[0].set_title('Partial Reconstruction (2) - best-case s.')
axs[0].legend()
axs[0].grid(True)

i_worst = 1 # worst trajectory:
axs[1].plot(est_trajectories[i_worst][:, 0, 0], est_trajectories[i_worst][:, 0, 1], est_trajectories[i_worst][:, 0, 2], color='blue', linewidth=1.0, alpha=0.7)
axs[1].plot(xt_true[:, 0, 0], xt_true[:, 0, 1], xt_true[:, 0, 2], color='red', linewidth=1.0, label='Correct Trajectory')
axs[1].scatter(xt_true[:, 0, 0][0], xt_true[:, 0, 1][0], xt_true[:, 0, 2][0], color='green', label='Start')
axs[1].scatter(xt_true[:, 0, 0][-1], xt_true[:, 0, 1][-1], xt_true[:, 0, 2][-1], color='red', label='End')
axs[1].set_title('Partial Reconstruction (2) - worst-case s.')
axs[1].legend()
axs[1].grid(True)
# Out:
# 5
# 1.0
# [10.152020078481028, 10.179020223091372, 9.3244563355384, 9.331451813180779, 9.368147616948649]
# 9.671019213448044

# %%
# evaluation:
x_id = 2
freq = 50
xt_true, est_trajectories, rmse = evaluation3D_partial(ode_name, ode_param, x_id, freq, n_sample, noise_ratio, alg, seed, n_seed, init_high, init_low)
print(rmse)

# 3D-plot:
fig, axs = plt.subplots(1, 2, figsize=(12, 6), subplot_kw={'projection': '3d'})

i_best = 4 # best trajectory:
axs[0].plot(est_trajectories[i_best][:, 0, 0], est_trajectories[i_best][:, 0, 1], est_trajectories[i_best][:, 0, 2], color='blue', linewidth=1.0, alpha=0.7)
axs[0].plot(xt_true[:, 0, 0], xt_true[:, 0, 1], xt_true[:, 0, 2], color='red', linewidth=1.0, label='Correct Trajectory')
axs[0].scatter(xt_true[:, 0, 0][0], xt_true[:, 0, 1][0], xt_true[:, 0, 2][0], color='green', label='Start')
axs[0].scatter(xt_true[:, 0, 0][-1], xt_true[:, 0, 1][-1], xt_true[:, 0, 2][-1], color='red', label='End')
axs[0].set_title('Partial Reconstruction (3) - best-case s.')
axs[0].legend()
axs[0].grid(True)

i_worst = 3 # worst trajectory:
axs[1].plot(est_trajectories[i_worst][:, 0, 0], est_trajectories[i_worst][:, 0, 1], est_trajectories[i_worst][:, 0, 2], color='blue', linewidth=1.0, alpha=0.7)
axs[1].plot(xt_true[:, 0, 0], xt_true[:, 0, 1], xt_true[:, 0, 2], color='red', linewidth=1.0, label='Correct Trajectory')
axs[1].scatter(xt_true[:, 0, 0][0], xt_true[:, 0, 1][0], xt_true[:, 0, 2][0], color='green', label='Start')
axs[1].scatter(xt_true[:, 0, 0][-1], xt_true[:, 0, 1][-1], xt_true[:, 0, 2][-1], color='red', label='End')
axs[1].set_title('Partial Reconstruction (3) - worst-case s.')
axs[1].legend()
axs[1].grid(True)
# Out:
# 5
# 0.0
# [10.197723416673096, 11.780813618999446, 11.386488567011318, 12.648042532896474, 9.561467356016417]
# 11.11490709831935

# %%
# evaluation:
x_id = 0
freq = 25
xt_true, est_trajectories, rmse = evaluation3D(ode_name, ode_param, x_id, freq, n_sample, noise_ratio, alg, seed, n_seed, init_high, init_low)
print(rmse)

# 3D-plot:
fig, axs = plt.subplots(1, 2, figsize=(12, 6), subplot_kw={'projection': '3d'})

i_best = 4 # best trajectory:
axs[0].plot(est_trajectories[i_best][:, 0, 0], est_trajectories[i_best][:, 0, 1], est_trajectories[i_best][:, 0, 2], color='blue', linewidth=1.0, alpha=0.7)
axs[0].plot(xt_true[:, 0, 0], xt_true[:, 0, 1], xt_true[:, 0, 2], color='red', linewidth=1.0, label='Correct Trajectory')
axs[0].scatter(xt_true[:, 0, 0][0], xt_true[:, 0, 1][0], xt_true[:, 0, 2][0], color='green', label='Start')
axs[0].scatter(xt_true[:, 0, 0][-1], xt_true[:, 0, 1][-1], xt_true[:, 0, 2][-1], color='red', label='End')
axs[0].set_title('Estimated Trajectories - best-case s.')
axs[0].legend()
axs[0].grid(True)

i_worst = 3 # worst trajectory:
axs[1].plot(est_trajectories[i_worst][:, 0, 0], est_trajectories[i_worst][:, 0, 1], est_trajectories[i_worst][:, 0, 2], color='blue', linewidth=1.0, alpha=0.7)
axs[1].plot(xt_true[:, 0, 0], xt_true[:, 0, 1], xt_true[:, 0, 2], color='red', linewidth=1.0, label='Correct Trajectory')
axs[1].scatter(xt_true[:, 0, 0][0], xt_true[:, 0, 1][0], xt_true[:, 0, 2][0], color='green', label='Start')
axs[1].scatter(xt_true[:, 0, 0][-1], xt_true[:, 0, 1][-1], xt_true[:, 0, 2][-1], color='red', label='End')
axs[1].set_title('Estimated Trajectories - worst-case s.')
axs[1].legend()
axs[1].grid(True)
# Out:
# 5
# 1.0
# 1.0
# 0.0
# [10.26144712701727, 12.700056753901295, 14.135746079584614, 15.357930230894048, 10.025250761277032]
# 12.49608619053485

# %%
rmse1 = 10.03
rmse2 = 15.36

fig, axs = plt.subplots(1, 2, figsize=(12, 0.5))

axs[0].text(0.5, 0.5, f'RMSE on trajectories: {rmse1}', ha='center', va='center', fontsize=12)
axs[0].axis('off')

axs[1].text(0.5, 0.5, f'RMSE on trajectories: {rmse2}', ha='center', va='center', fontsize=12)
axs[1].axis('off')

plt.show()

# %% [markdown]
# ### Parametrization on $\sigma$

# %%
# select the ODE:
ode_name = 'Lorenz_sigma'
init_high = [5, 5, 5, 10.0]
init_low = [5, 5, 5, 10.0]

ode_param=None
n_sample = 50 
noise_ratio = 0.01 # RMK. con 0.09 funziona meglio  
alg = 'diff'
seed = 0
n_seed = 5

# %%
# evaluation:
x_id = 0
freq = 25
xt_true_s, est_trajectories_s, rmse_s = evaluation3D_partial_p(ode_name, ode_param, x_id, freq, n_sample, noise_ratio, alg, seed, n_seed, init_high, init_low)
print(rmse_s)

# 3D-plot:
fig, axs = plt.subplots(1, 2, figsize=(12, 6), subplot_kw={'projection': '3d'})

i_best = 0 # best trajectory:
axs[0].plot(est_trajectories_s[i_best][:, 0, 0], est_trajectories_s[i_best][:, 0, 1], est_trajectories_s[i_best][:, 0, 2], color='blue', linewidth=1.0, alpha=0.7)
axs[0].plot(xt_true_s[:, 0, 0], xt_true_s[:, 0, 1], xt_true_s[:, 0, 2], color='red', linewidth=1.0, label='Correct Trajectory')
axs[0].scatter(xt_true_s[:, 0, 0][0], xt_true_s[:, 0, 1][0], xt_true_s[:, 0, 2][0], color='green', label='Start')
axs[0].scatter(xt_true_s[:, 0, 0][-1], xt_true_s[:, 0, 1][-1], xt_true_s[:, 0, 2][-1], color='red', label='End')
axs[0].set_title('Partial Reconstruction (1) - best-case s.')
axs[0].legend()
axs[0].grid(True)

i_worst = 1 # worst trajectory:
axs[1].plot(est_trajectories_s[i_worst][:, 0, 0], est_trajectories_s[i_worst][:, 0, 1], est_trajectories_s[i_worst][:, 0, 2], color='blue', linewidth=1.0, alpha=0.7)
axs[1].plot(xt_true_s[:, 0, 0], xt_true_s[:, 0, 1], xt_true_s[:, 0, 2], color='red', linewidth=1.0, label='Correct Trajectory')
axs[1].scatter(xt_true_s[:, 0, 0][0], xt_true_s[:, 0, 1][0], xt_true_s[:, 0, 2][0], color='green', label='Start')
axs[1].scatter(xt_true_s[:, 0, 0][-1], xt_true_s[:, 0, 1][-1], xt_true_s[:, 0, 2][-1], color='red', label='End')
axs[1].set_title('Partial Reconstruction (1) - worst-case s.')
axs[1].legend()
axs[1].grid(True)
# Out:
# 5
# 0.0
# [10.044813655299578, 11.237491428975323, 11.007917207358107, 10.18904368979969, 10.331556597540562]
# 10.562164515794652

# %%
# RMSE:

# seed:
np.random.seed(333)

N = 50
a, b = 0.0, 10.0  # first input interval
c, d = 0.0, 10.0  # second input interval
e, f = 0.0, 10.0  # third input interval
g, h = 9.5, 10.5
init_point = np.empty((N, 4))
init_point[:, 0] = np.random.uniform(a, b, N) 
init_point[:, 1] = np.random.uniform(c, d, N) 
init_point[:, 2] = np.random.uniform(e, f, N)  
init_point[:, 3] = np.random.uniform(g, h, N) 

# print(np.shape(init_point))
print(init_point[0])

RMSE_sigma = evaluation3D_partial_p(ode_name, ode_param, x_id, freq, n_sample, noise_ratio, alg, seed, n_seed, init_high, init_low, N, init_point)
print('RMSE (overall): ', RMSE_sigma)
# Out:
# [5.43291087 1.90547842 9.19701301 9.78877543]
# 5
# 0.0
# [9.843984760149075, 9.925602978515036, 9.825175458442013, 9.938700210722885, 9.840736607862743]
# RMSE (overall):  9.87484000313835

# %% [markdown]
# ### Parametrization on $\rho$

# %%
# select the ODE:
ode_name = 'Lorenz_rho'
init_high = [5, 5, 5, 28.0]
init_low = [5, 5, 5, 28.0]

ode_param=None
n_sample = 50 
noise_ratio = 0.01 # RMK. con 0.09 funziona meglio  
alg = 'diff'
seed = 0
n_seed = 5

# %%
# evaluation:
x_id = 1
freq = 50
xt_true_r, est_trajectories_r, rmse_r = evaluation3D_partial_p(ode_name, ode_param, x_id, freq, n_sample, noise_ratio, alg, seed, n_seed, init_high, init_low)
print(rmse_r)

# 3D-plot:
fig, axs = plt.subplots(1, 2, figsize=(12, 6), subplot_kw={'projection': '3d'})

i_best = 2 # best trajectory:
axs[0].plot(est_trajectories_r[i_best][:, 0, 0], est_trajectories_r[i_best][:, 0, 1], est_trajectories_r[i_best][:, 0, 2], color='blue', linewidth=1.0, alpha=0.7)
axs[0].plot(xt_true_r[:, 0, 0], xt_true_r[:, 0, 1], xt_true_r[:, 0, 2], color='red', linewidth=1.0, label='Correct Trajectory')
axs[0].scatter(xt_true_r[:, 0, 0][0], xt_true_r[:, 0, 1][0], xt_true_r[:, 0, 2][0], color='green', label='Start')
axs[0].scatter(xt_true_r[:, 0, 0][-1], xt_true_r[:, 0, 1][-1], xt_true_r[:, 0, 2][-1], color='red', label='End')
axs[0].set_title('Partial Reconstruction (2) - best-case s.')
axs[0].legend()
axs[0].grid(True)

i_worst = 0 # worst trajectory:
axs[1].plot(est_trajectories_r[i_worst][:, 0, 0], est_trajectories_r[i_worst][:, 0, 1], est_trajectories_r[i_worst][:, 0, 2], color='blue', linewidth=1.0, alpha=0.7)
axs[1].plot(xt_true_r[:, 0, 0], xt_true_r[:, 0, 1], xt_true_r[:, 0, 2], color='red', linewidth=1.0, label='Correct Trajectory')
axs[1].scatter(xt_true_r[:, 0, 0][0], xt_true_r[:, 0, 1][0], xt_true_r[:, 0, 2][0], color='green', label='Start')
axs[1].scatter(xt_true_r[:, 0, 0][-1], xt_true_r[:, 0, 1][-1], xt_true_r[:, 0, 2][-1], color='red', label='End')
axs[1].set_title('Partial Reconstruction (2) - worst-case s.')
axs[1].legend()
axs[1].grid(True)
# Out:
# 5
# 0.0
# [10.186072195777285, 9.304223620032994, 9.304229892156265, 9.304222328931678, 9.304222328931678]
# 9.48059407316598

# %%
# RMSE:

# seed:
np.random.seed(333)

N = 50
a, b = 0.0, 10.0  # first input interval
c, d = 0.0, 10.0  # second input interval
e, f = 0.0, 10.0  # third input interval
g, h = 27.5, 28.5
init_point = np.empty((N, 4))
init_point[:, 0] = np.random.uniform(a, b, N) 
init_point[:, 1] = np.random.uniform(c, d, N) 
init_point[:, 2] = np.random.uniform(e, f, N)  
init_point[:, 3] = np.random.uniform(g, h, N) 

# print(np.shape(init_point))
print(init_point[0])

RMSE_rho = evaluation3D_partial_p(ode_name, ode_param, x_id, freq, n_sample, noise_ratio, alg, seed, n_seed, init_high, init_low, N, init_point)
print('RMSE (overall): ', RMSE_rho)
# Out:
# [ 5.43291087  1.90547842  9.19701301 27.78877543]
# 5
# 0.0
# [8.846817548151535, 8.24415672348453, 8.244120420507747, 8.24424013718825, 8.24424013718825]
# RMSE (overall):  8.364714993304062

# %% [markdown]
# ### Parametrization on $\beta$

# %%
# select the ODE:
ode_name = 'Lorenz_beta'
init_high = [5, 5, 5, 8/3]
init_low = [5, 5, 5, 8/3]

ode_param=None
n_sample = 50 
noise_ratio = 0.01 # RMK. con 0.09 funziona meglio  
alg = 'diff'
seed = 0
n_seed = 5

# %%
# evaluation:
x_id = 2
freq = 50
xt_true_b, est_trajectories_b, rmse_b = evaluation3D_partial_p(ode_name, ode_param, x_id, freq, n_sample, noise_ratio, alg, seed, n_seed, init_high, init_low)
print(rmse_b)

# 3D-plot:
fig, axs = plt.subplots(1, 2, figsize=(12, 6), subplot_kw={'projection': '3d'})

i_best = 0 # best trajectory:
axs[0].plot(est_trajectories_b[i_best][:, 0, 0], est_trajectories_b[i_best][:, 0, 1], est_trajectories_b[i_best][:, 0, 2], color='blue', linewidth=1.0, alpha=0.7)
axs[0].plot(xt_true_b[:, 0, 0], xt_true_b[:, 0, 1], xt_true_b[:, 0, 2], color='red', linewidth=1.0, label='Correct Trajectory')
axs[0].scatter(xt_true_b[:, 0, 0][0], xt_true_b[:, 0, 1][0], xt_true_b[:, 0, 2][0], color='green', label='Start')
axs[0].scatter(xt_true_b[:, 0, 0][-1], xt_true_b[:, 0, 1][-1], xt_true_b[:, 0, 2][-1], color='red', label='End')
axs[0].set_title('Partial Reconstruction (3) - best-case s.')
axs[0].legend()
axs[0].grid(True)

i_worst = 2 # worst trajectory:
axs[1].plot(est_trajectories_b[i_worst][:, 0, 0], est_trajectories_b[i_worst][:, 0, 1], est_trajectories_b[i_worst][:, 0, 2], color='blue', linewidth=1.0, alpha=0.7)
axs[1].plot(xt_true_b[:, 0, 0], xt_true_b[:, 0, 1], xt_true_b[:, 0, 2], color='red', linewidth=1.0, label='Correct Trajectory')
axs[1].scatter(xt_true_b[:, 0, 0][0], xt_true_b[:, 0, 1][0], xt_true_b[:, 0, 2][0], color='green', label='Start')
axs[1].scatter(xt_true_b[:, 0, 0][-1], xt_true_b[:, 0, 1][-1], xt_true_b[:, 0, 2][-1], color='red', label='End')
axs[1].set_title('Partial Reconstruction (3) - worst-case s.')
axs[1].legend()
axs[1].grid(True)
# Out:
# 5
# 0.0
# [10.584639765026507, 10.584615744276935, 11.964212370900425, 10.584628158831348, 10.584621957940136]
# 10.86054359939507

# %%
# RMSE:

# seed:
np.random.seed(333)

N = 50
a, b = 0.0, 10.0  # first input interval
c, d = 0.0, 10.0  # second input interval
e, f = 0.0, 10.0  # third input interval
g, h = 7/3, 9/3
init_point = np.empty((N, 4))
init_point[:, 0] = np.random.uniform(a, b, N) 
init_point[:, 1] = np.random.uniform(c, d, N) 
init_point[:, 2] = np.random.uniform(e, f, N)  
init_point[:, 3] = np.random.uniform(g, h, N) 

# print(np.shape(init_point))
print(init_point[0])

RMSE_beta = evaluation3D_partial_p(ode_name, ode_param, x_id, freq, n_sample, noise_ratio, alg, seed, n_seed, init_high, init_low, N, init_point)
print('RMSE (overall): ', RMSE_beta)
# Out:
# [5.43291087 1.90547842 9.19701301 2.52585029]
# 5
# 0.0
# [11.003629067336545, 11.00362979187265, 11.27449220618495, 11.003627798711534, 11.0036173191205]
# RMSE (overall):  11.057799236645236

# %% [markdown]
# ### plot x report:

# %%
fig, axs = plt.subplots(1, 3, figsize=(16, 5), subplot_kw={'projection': '3d'})

i_best = 0 # best trajectory:
axs[0].plot(est_trajectories_s[i_best][:, 0, 0], est_trajectories_s[i_best][:, 0, 1], est_trajectories_s[i_best][:, 0, 2], color='blue', linewidth=1.0, alpha=0.7)
axs[0].plot(xt_true_s[:, 0, 0], xt_true_s[:, 0, 1], xt_true_s[:, 0, 2], color='red', linewidth=1.0, label='Correct Trajectory')
axs[0].scatter(xt_true_s[:, 0, 0][0], xt_true_s[:, 0, 1][0], xt_true_s[:, 0, 2][0], color='green', label='Start')
axs[0].scatter(xt_true_s[:, 0, 0][-1], xt_true_s[:, 0, 1][-1], xt_true_s[:, 0, 2][-1], color='red', label='End')
axs[0].set_title(r'Equation (4) Estimate, Param. $\sigma$ ')
axs[0].legend()
axs[0].grid(True)

i_best = 2 # best trajectory:
axs[1].plot(est_trajectories_r[i_best][:, 0, 0], est_trajectories_r[i_best][:, 0, 1], est_trajectories_r[i_best][:, 0, 2], color='blue', linewidth=1.0, alpha=0.7)
axs[1].plot(xt_true_r[:, 0, 0], xt_true_r[:, 0, 1], xt_true_r[:, 0, 2], color='red', linewidth=1.0, label='Correct Trajectory')
axs[1].scatter(xt_true_r[:, 0, 0][0], xt_true_r[:, 0, 1][0], xt_true_r[:, 0, 2][0], color='green', label='Start')
axs[1].scatter(xt_true_r[:, 0, 0][-1], xt_true_r[:, 0, 1][-1], xt_true_r[:, 0, 2][-1], color='red', label='End')
axs[1].set_title(r'Equation (5) Estimate, Param. $\rho$')
axs[1].legend()
axs[1].grid(True)

i_best = 0 # best trajectory:
axs[2].plot(est_trajectories_b[i_best][:, 0, 0], est_trajectories_b[i_best][:, 0, 1], est_trajectories_b[i_best][:, 0, 2], color='blue', linewidth=1.0, alpha=0.7)
axs[2].plot(xt_true_b[:, 0, 0], xt_true_b[:, 0, 1], xt_true_b[:, 0, 2], color='red', linewidth=1.0, label='Correct Trajectory')
axs[2].scatter(xt_true_b[:, 0, 0][0], xt_true_b[:, 0, 1][0], xt_true_b[:, 0, 2][0], color='green', label='Start')
axs[2].scatter(xt_true_b[:, 0, 0][-1], xt_true_b[:, 0, 1][-1], xt_true_b[:, 0, 2][-1], color='red', label='End')
axs[2].set_title(r'Equation (6) Estimate, Param. $\beta$')
axs[2].legend()
axs[2].grid(True)

# %%
rmse1 = 10.56
rmse2 = 9.48
rmse3 = 10.86

fig, axs = plt.subplots(1, 3, figsize=(16, 0.5))

axs[0].text(0.5, 0.5, f'RMSE on trajectories: {rmse1}', ha='center', va='center', fontsize=12)
axs[0].axis('off')

axs[1].text(0.5, 0.5, f'RMSE on trajectories: {rmse2}', ha='center', va='center', fontsize=12)
axs[1].axis('off')

axs[2].text(0.5, 0.5, f'RMSE on trajectories: {rmse3}', ha='center', va='center', fontsize=12)  
axs[2].axis('off')

plt.show()
