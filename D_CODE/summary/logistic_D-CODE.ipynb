# %% [markdown]
# ### Logistic Model - D-CODE performance:

# %%
# add the parent directory to the system path:
import sys
from pathlib import Path
parent_dir = Path('..').resolve() 
sys.path.append(str(parent_dir)) 

# import:
import numpy as np
import os
import matplotlib.pyplot as plt
import equations
from evaluation_trajectories import evaluation1D, evaluation1D_p, evaluation1D_2p 

# seed:
np.random.seed(666)

# %% [markdown]
# ### Parametrization on $k$ - run 1
# population_size = 15k
# init_range = [0.1, 0.9]
#
# !!! DO NOT RUN !!!

# %%
# select the ODE:
ode_name = 'LogisticODE_k'
init_high = [0.05, 0.5]
init_low = [0.05, 0.5]

ode_param=None
x_id = 0
freq = 5
n_sample = 50 
noise_ratio = 0.01
alg = 'vi'
seed = 0
n_seed = 5
N = 1

ode = equations.get_ode(ode_name, ode_param)
dt = 1 / freq
time_vector_b = np.arange(0, ode.T + dt, dt)

# %%
# evaluation: 
xt_true_b, est_trajectories_b, rmse_b = evaluation1D_p(ode_name, ode_param, x_id, freq, n_sample, noise_ratio, alg, seed, n_seed, init_high, init_low)
print('RMSE on test-case 0: ', rmse_b)

# plot:
plt.figure(figsize=(5, 4))

for i in range(np.shape(est_trajectories_b)[0]):
    plt.plot(time_vector_b, est_trajectories_b[i][:, 0, 0], color='blue', linewidth=0.5, alpha=0.7)

plt.plot(time_vector_b, xt_true_b[:, 0, 0], color='red', linewidth=1.0, label='Correct Trajectory')

plt.scatter(time_vector_b[0], xt_true_b[:, 0, 0][0], color='green', label='Start')
plt.scatter(time_vector_b[-1], xt_true_b[:, 0, 0][-1], color='red', label='End')

plt.title('Estimated Trajectories - Param. $b$')
plt.legend()
plt.grid(True)
# Out:
# 5
# 0.4
# [0.00436492727567114, 0.11917571441436269, 3.3538266351960715e-15, 0.11911370856451738, 0.13729239304744284]
# RMSE on test-case 0:  0.07598934866039948

# %%
# RMSE: 

N = 50
a, b = 0.0, 0.1  # first input interval
c, d = 0.1, 0.9  # second input interval
init_point = np.empty((N, 2))
init_point[:, 0] = np.random.uniform(a, b, N) 
init_point[:, 1] = np.random.uniform(c, d, N) 
#print(init_point)
#print(np.shape(init_point))

RMSEb = evaluation1D_p(ode_name, ode_param, x_id, freq, n_sample, noise_ratio, alg, seed, n_seed, init_high, init_low, N, init_point)
print('RMSE (overall): ', RMSEb)
# Out:
# 5
# 0.4
# [0.006604919139001048, 0.13113389666454112, 6.387509694708173e-13, 0.1309053766077621, 0.1403789383346607]
# RMSE (overall):  0.08180462614932074

# %% [markdown]
# ### Parametrization on $k$ - run 2
#
# population_size = 30k
# init_range = [0.1, 0.9]
#
# !!! DO NOT RUN !!!

# %%
# select the ODE:
ode_name = 'LogisticODE_k'
init_high = [0.05, 0.5]
init_low = [0.05, 0.5]

ode_param=None
x_id = 0
freq = 5
n_sample = 50 
noise_ratio = 0.01
alg = 'vi'
seed = 0
n_seed = 5
N = 1

ode = equations.get_ode(ode_name, ode_param)
dt = 1 / freq
time_vector_b = np.arange(0, ode.T + dt, dt)

# %%
# evaluation: 
xt_true_b, est_trajectories_b, rmse_b = evaluation1D_p(ode_name, ode_param, x_id, freq, n_sample, noise_ratio, alg, seed, n_seed, init_high, init_low)
print('RMSE on test-case 0: ', rmse_b)

# plot:
plt.figure(figsize=(5, 4))

for i in range(np.shape(est_trajectories_b)[0]):
    plt.plot(time_vector_b, est_trajectories_b[i][:, 0, 0], color='blue', linewidth=0.5, alpha=0.7)

plt.plot(time_vector_b, xt_true_b[:, 0, 0], color='red', linewidth=1.0, label='Correct Trajectory')

plt.scatter(time_vector_b[0], xt_true_b[:, 0, 0][0], color='green', label='Start')
plt.scatter(time_vector_b[-1], xt_true_b[:, 0, 0][-1], color='red', label='End')

plt.title('Estimated Trajectories - Param. $b$')
plt.legend()
plt.grid(True)
# Out:
# 5
# 0.2
# [0.05964548769139652, 0.12607289086266174, 0.13001509950888163, 0.08139339536218512, 3.3538266351960715e-15]
# RMSE on test-case 0:  0.07942537468502567

# %%
# RMSE: 

N = 50
a, b = 0.0, 0.1  # first input interval
c, d = 0.1, 0.9  # second input interval
init_point = np.empty((N, 2))
init_point[:, 0] = np.random.uniform(a, b, N) 
init_point[:, 1] = np.random.uniform(c, d, N) 
#print(init_point)
#print(np.shape(init_point))

RMSEb = evaluation1D_p(ode_name, ode_param, x_id, freq, n_sample, noise_ratio, alg, seed, n_seed, init_high, init_low, N, init_point)
print('RMSE (overall): ', RMSEb)
# Out:
# 5
# 0.2
# [0.0752396393030436, 0.13441086261826063, 0.13675793039825612, 0.10641842649851757, 6.387509694708173e-13]
# RMSE (overall):  0.09056537176374334

# %% [markdown]
# ### Parametrization on $k$ - run 3
#
# population_size = 20k
# init_range = [0.3, 0.7]
#
# !!! DO NOT RUN !!!

# %%
# select the ODE:
ode_name = 'LogisticODE_k'
init_high = [0.05, 0.5]
init_low = [0.05, 0.5]

ode_param=None
x_id = 0
freq = 5
n_sample = 50 
noise_ratio = 0.01
alg = 'vi'
seed = 0
n_seed = 5
N = 1

ode = equations.get_ode(ode_name, ode_param)
dt = 1 / freq
time_vector_b = np.arange(0, ode.T + dt, dt)

# %%
# evaluation: 
xt_true_b, est_trajectories_b, rmse_b = evaluation1D_p(ode_name, ode_param, x_id, freq, n_sample, noise_ratio, alg, seed, n_seed, init_high, init_low)
print('RMSE on test-case 0: ', rmse_b)

# plot:
plt.figure(figsize=(5, 4))

for i in range(np.shape(est_trajectories_b)[0]):
    plt.plot(time_vector_b, est_trajectories_b[i][:, 0, 0], color='blue', linewidth=0.5, alpha=0.7)

plt.plot(time_vector_b, xt_true_b[:, 0, 0], color='red', linewidth=1.0, label='Correct Trajectory')

plt.scatter(time_vector_b[0], xt_true_b[:, 0, 0][0], color='green', label='Start')
plt.scatter(time_vector_b[-1], xt_true_b[:, 0, 0][-1], color='red', label='End')

plt.title('Estimated Trajectories - Param. $b$')
plt.legend()
plt.grid(True)
# Out:
# 5
# 0.8
# [0.027640363042284496, 3.3538266351960715e-15, 0.001229460086620951, 0.0008564662840035239, 0.04378321126924447]
# RMSE on test-case 0:  0.01470190013643136

# %%
# RMSE: 

N = 50
a, b = 0.0, 0.1  # first input interval
c, d = 0.1, 0.9  # second input interval
init_point = np.empty((N, 2))
init_point[:, 0] = np.random.uniform(a, b, N) 
init_point[:, 1] = np.random.uniform(c, d, N) 
#print(init_point)
#print(np.shape(init_point))

RMSEb = evaluation1D_p(ode_name, ode_param, x_id, freq, n_sample, noise_ratio, alg, seed, n_seed, init_high, init_low, N, init_point)
print('RMSE (overall): ', RMSEb)
# Out:
# 5
# 0.8
# [0.20339250541861545, 6.387509694708173e-13, 0.001857433827268924, 0.0012923767944042867, 0.067575246769509]
# RMSE (overall):  0.05482351256208727

# %%
# generalization test: 
xt_true_b, est_trajectories_b, rmse_b = evaluation1D_p(ode_name, ode_param, x_id, freq, n_sample, noise_ratio, alg, seed, n_seed, [0.05, 0.1], [0.05, 0.1])
print('RMSE on test-case 0: ', rmse_b)

# plot:
plt.figure(figsize=(5, 4))

for i in range(np.shape(est_trajectories_b)[0]):
    plt.plot(time_vector_b, est_trajectories_b[i][:, 0, 0], color='blue', linewidth=0.5, alpha=0.7)

plt.plot(time_vector_b, xt_true_b[:, 0, 0], color='red', linewidth=1.0, label='Correct Trajectory')

plt.scatter(time_vector_b[0], xt_true_b[:, 0, 0][0], color='green', label='Start')
plt.scatter(time_vector_b[-1], xt_true_b[:, 0, 0][-1], color='red', label='End')

plt.title('Estimated Trajectories - Param. $b$')
plt.legend()
plt.grid(True)
# Out:
# 5
# 0.8
# [0.49820591814860005, 7.864633189107487e-15, 0.003257129273546386, 0.002263699926840111, 0.13146016772282057]
# RMSE on test-case 0:  0.127037383014363

# %% [markdown]
# ### Parametrization on $k$ - run 4
#
# population_size = 20k
# init_range = [0.2, 0.8]

# %%
# select the ODE:
ode_name = 'LogisticODE_k'
init_high = [0.05, 0.5]
init_low = [0.05, 0.5]

ode_param=None
x_id = 0
freq = 5
n_sample = 50 
noise_ratio = 0.01
alg = 'vi'
seed = 0
n_seed = 5
N = 1

ode = equations.get_ode(ode_name, ode_param)
dt = 1 / freq
time_vector_b = np.arange(0, ode.T + dt, dt)

# %%
# evaluation: 
xt_true_b, est_trajectories_b, rmse_b = evaluation1D_p(ode_name, ode_param, x_id, freq, n_sample, noise_ratio, alg, seed, n_seed, init_high, init_low)
print('RMSE on test-case 0: ', rmse_b)

# plot:
plt.figure(figsize=(5, 4))

for i in range(np.shape(est_trajectories_b)[0]):
    plt.plot(time_vector_b, est_trajectories_b[i][:, 0, 0], color='blue', linewidth=0.5, alpha=0.7)

plt.plot(time_vector_b, xt_true_b[:, 0, 0], color='red', linewidth=1.0, label='Correct Trajectory')

plt.scatter(time_vector_b[0], xt_true_b[:, 0, 0][0], color='green', label='Start')
plt.scatter(time_vector_b[-1], xt_true_b[:, 0, 0][-1], color='red', label='End')

plt.title('D-CODE - Estimated Trajectories')
plt.legend()
plt.grid(True)
# Out:
# 5
# 0.6
# [0.09117592669162845, 0.0012031609706995988, 0.0047724391074897956, 3.3538266351960715e-15, 0.13321222650108536]
# RMSE on test-case 0:  0.046072750654181316

# %%
# RMSE: 

N = 50
a, b = 0.0, 0.1  # first input interval
c, d = 0.2, 0.8  # second input interval
init_point = np.empty((N, 2))
init_point[:, 0] = np.random.uniform(a, b, N) 
init_point[:, 1] = np.random.uniform(c, d, N) 
#print(init_point)
#print(np.shape(init_point))

RMSEb = evaluation1D_p(ode_name, ode_param, x_id, freq, n_sample, noise_ratio, alg, seed, n_seed, init_high, init_low, N, init_point)
print('RMSE (overall): ', RMSEb)
# Out:
# 5
# 0.6
# [0.11607858615949475, 0.001603534524561841, 0.0063606793947041055, 1.6796191735490735e-14, 0.14793491485751525]
# RMSE (overall):  0.05439554298725855

# %%
# generalization test: 
xt_true_b, est_trajectories_b, rmse_b = evaluation1D_p(ode_name, ode_param, x_id, freq, n_sample, noise_ratio, alg, seed, n_seed, [0.05, 1.1], [0.05, 1.1])
print('RMSE on test-case 0: ', rmse_b)

# plot:
plt.figure(figsize=(5, 4))

for i in range(np.shape(est_trajectories_b)[0]):
    plt.plot(time_vector_b, est_trajectories_b[i][:, 0, 0], color='blue', linewidth=0.5, alpha=0.7)

plt.plot(time_vector_b, xt_true_b[:, 0, 0], color='red', linewidth=1.0, label='Correct Trajectory')

plt.scatter(time_vector_b[0], xt_true_b[:, 0, 0][0], color='green', label='Start')
plt.scatter(time_vector_b[-1], xt_true_b[:, 0, 0][-1], color='red', label='End')

plt.title('D-CODE - Estimated Trajectories')
plt.legend()
plt.grid(True)
# Out:
# 5
# 0.6
# [0.06115692341389973, 0.0003096960786732338, 0.0012322900268590066, 1.3620592176677315e-14, 0.03359180678244952]
# RMSE on test-case 0:  0.01925814326037902
